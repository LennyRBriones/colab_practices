# %% [markdown]
# <a href="https://colab.research.google.com/github/LennRBriones/colab_practices/blob/main/Sharing_a_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio de compartir colab

# %% [markdown]
# ![df1e5bf3-7e4d-40e1-af70-a9c416638f5a.jpg](data:image/jpeg;base64,...)

# %%
# %timeit max(range(1000000))
# Out:
# 16.8 ms ± 191 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
